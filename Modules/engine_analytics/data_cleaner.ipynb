# %% [markdown]
# ## this is the data cleaning pipeline for the spiders
#
# 1: Open the Db
# 2: fill in the columns with deafult values if NAN
# 3: from the address find the postal code.
# 4: standardize the columns.
# 5: convert columns to categorical data.
#
#      write the data to DB in a new table

# %%
# libraries import
from pathlib import Path
import sys

import pandas as pd
import numpy as np
import importlib

#==== Standard Object (scraper) DB access
current = Path.cwd()

for parent in [current, *current.parents]:
    if (parent / "Modules").exists():
        sys.path.append(str(parent))
        print(f"found root: {parent}")
        break

from Modules.spiders.spider_default_obj.spider_default_obj import Post_Data
# Out:
# found root: /home/chris/Desktop/4260_presentation

# %% [markdown]
# ## 1: import the database with the data.

# %%
post=Post_Data()

post.test_connection_to_post_data_object()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 post=Post_Data()
#       2
# ----> 3 post.test_connection_to_post_data_object()
#
# AttributeError: 'Post_Data' object has no attribute 'test_connection_to_post_data_object'
